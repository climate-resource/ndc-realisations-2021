# %%
# %load_ext nb_black

# %%
import os
import pyam
import scmdata

import matplotlib.pyplot as plt

from ndcs.constants import PROCESSED_DATA_DIR, NDC_TARGET_RELEASE

# %%
# Load Engage data

# %%
conn = pyam.iiasa.Connection()
conn.valid_connections
# Out:
# pyam - INFO: Running in a notebook, setting up a basic logging at level INFO
# pyam.iiasa - INFO: You are connected as an anonymous user
# ['ariadne',
#  'cdlinks',
#  'cmin',
#  'commit',
#  'deeds',
#  'engage',
#  'hotspots',
#  'integration-test',
#  'nexus-basins',
#  'ngfs',
#  'ngfs_2',
#  'openentrance',
#  'paris_lttg',
#  'ripples',
#  'senses',
#  'setnav',
#  'iamc15',
#  'iamc15-qa',
#  'sandbox']

# %%
df = pyam.read_iiasa(
    "engage",
    variable=[
        "Emissions|*",
        "AR5 climate diagnostics|Temperature|Global Mean|MAGICC6|MED",
        "Diagnostics|MAGICC6|Harmonized Input|Emissions*",
    ],
    region="World",
)
df
# Out:
# pyam.iiasa - INFO: You are connected to the IXSE_ENGAGE scenario explorer hosted by IIASA. If you use this data in any published format, please cite the data as provided in the explorer guidelines: https://data.ene.iiasa.ac.at/engage/#/about
# pyam.iiasa - INFO: You are connected as an anonymous user
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : AIM/CGE V2.2, COFFEE 1.1, GEM-E3 V2021, IMAGE 3.0, ... WITCH 5.0 (10)
#  * scenario : Baseline, EN_Baseline_1000, EN_Baseline_550, ... SmartUse (204)
# Timeseries data coordinates:
#    region   : World (1)
#    variable : ... (126)
#    unit     : GtC, Mt, Mt BC/yr, Mt CH4/yr, Mt CO/yr, ... °C rel. to 1850-1900 (35)
#    year     : 1990, 1995, 2000, 2001, 2002, 2003, 2004, 2005, ... 2100 (103)
# Meta indicators:
#    version (object) 1, 2, 3, 4 (4)
#    exclude (bool) False (1)

# %% [markdown]
# Use version 2 in line with Riahi et al. (see bottom of https://data.ene.iiasa.ac.at/engage/#/about which points to https://zenodo.org/record/5553976).

# %%
VERSION_TO_USE = 2

# %%
db = scmdata.ScmRun(
    df.filter(version=VERSION_TO_USE)
    .timeseries()
    .reset_index()
    .set_index(["model", "scenario"])
    .join(df.meta["version"])
)
db["model_scenario"] = db["model"] + "_" + db["scenario"]
db
# Out:
# <ScmRun (timeseries: 12253, timepoints: 103)>
# Time:
# 	Start: 1990-01-01T00:00:00
# 	End: 2100-01-01T00:00:00
# Meta:
# 	              model                   model_scenario region            scenario                  unit                                                                         variable  version
# 	0      AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f  °C rel. to 1850-1900                      AR5 climate diagnostics|Temperature|Global Mean|MAGICC6|MED        2
# 	1      AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f                    Mt                                Diagnostics|MAGICC6|Harmonized Input|Emissions|BC        2
# 	2      AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f                    kt                              Diagnostics|MAGICC6|Harmonized Input|Emissions|C2F6        2
# 	3      AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f                    kt                             Diagnostics|MAGICC6|Harmonized Input|Emissions|C6F14        2
# 	4      AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f                 MtCH4                               Diagnostics|MAGICC6|Harmonized Input|Emissions|CH4        2
# 	5      AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f                  MtCO                                Diagnostics|MAGICC6|Harmonized Input|Emissions|CO        2
# 	6      AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f                   GtC                         Diagnostics|MAGICC6|Harmonized Input|Emissions|CO2|AFOLU        2
# 	7      AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f                   GtC  Diagnostics|MAGICC6|Harmonized Input|Emissions|CO2|Energy and Industrial Pro...        2
# 	8      AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f                    kt                        Diagnostics|MAGICC6|Harmonized Input|Emissions|HFC|HFC125        2
# 	9      AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f                    kt                       Diagnostics|MAGICC6|Harmonized Input|Emissions|HFC|HFC134a        2
# 	...             ...                              ...    ...                 ...                   ...                                                                              ...      ...
# 	12243     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy             kt N2O/yr                                                                    Emissions|N2O        2
# 	12244     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy             kt N2O/yr                                                              Emissions|N2O|AFOLU        2
# 	12245     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy             Mt NH3/yr                                                                    Emissions|NH3        2
# 	12246     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy             Mt NO2/yr                                                                    Emissions|NOx        2
# 	12247     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy              Mt OC/yr                                                                     Emissions|OC        2
# 	12248     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy       kt CF4-equiv/yr                                                                    Emissions|PFC        2
# 	12249     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy             kt SF6/yr                                                                    Emissions|SF6        2
# 	12250     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy             Mt SO2/yr                                                                 Emissions|Sulfur        2
# 	12251     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy             Mt VOC/yr                                                                    Emissions|VOC        2
# 	12252     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy             Mt CO2/yr                           Emissions|CO2|Energy|Demand|Residential and Commercial        2
#
# 	[12253 rows x 7 columns]

# %% [markdown]
# # Load ndc scenarios

# %%
target_scenario = "2021-11-09_1__high__C__SSP1BL__exclude"

# %%
ndc_emissions = (
    scmdata.ScmRun(
        os.path.join(
            PROCESSED_DATA_DIR,
            "global_emissions_pathways",
            NDC_TARGET_RELEASE,
            "emissions_ghg_extended.csv",
        )
    )
    .filter(scenario=target_scenario)
    .convert_unit("GtCO2 / yr")
)
ndc_emissions
# Out:
# scmdata.run - INFO: Reading /home/jared/code/cr/ndc-realisations-2021/src/ndcs/../../data/processed/global_emissions_pathways/12Nov2021a_CR/emissions_ghg_extended.csv
# <ScmRun (timeseries: 1, timepoints: 86)>
# Time:
# 	Start: 2015-01-01T00:00:00
# 	End: 2100-01-01T00:00:00
# Meta:
# 	  ambition conditionality country_extension        date exclude_hot_air  global_extension last_country  ... pathway_num pathway_num_today  region                                scenario     stage        unit  \
# 	0     high              C            SSP1BL  2021-11-09         exclude               NaN          VEN  ...         354                 1   World  2021-11-09_1__high__C__SSP1BL__exclude  extended  GtCO2 / yr
#
# 	                                   variable
# 	0  Emissions|GHG excl CO2 AFOLU (AR6GWP100)
#
# 	[1 rows x 16 columns]

# %%
OUT_SENSITIVITY_FNAME = os.path.join(
    PROCESSED_DATA_DIR,
    "climate_assessment",
    "merged",
    f"output_{NDC_TARGET_RELEASE}_sensitivity.csv",
)
ndc_temperatures = scmdata.ScmRun(OUT_SENSITIVITY_FNAME).filter(
    scenario=target_scenario,
    quantile=0.5,
    variable="Surface Temperature (GSAT)|MAGICCv7.5.3",
)
ndc_temperatures
# Out:
# scmdata.run - INFO: Reading /home/jared/code/cr/ndc-realisations-2021/src/ndcs/../../data/processed/climate_assessment/merged/output_12Nov2021a_CR_sensitivity.csv
# <ScmRun (timeseries: 1, timepoints: 106)>
# Time:
# 	Start: 1995-01-01T00:00:00
# 	End: 2100-01-01T00:00:00
# Meta:
# 	      ambition conditionality country_extension exclude_hot_air label  methane_pledges          model    pathway_id  quantile region                                scenario unit                                 variable
# 	14946     high              C            SSP1BL         exclude     A              NaN  NDC Factsheet  2021-11-09_1       0.5  World  2021-11-09_1__high__C__SSP1BL__exclude    K  Surface Temperature (GSAT)|MAGICCv7.5.3

# %% [markdown]
# # Find similar pathways

# %%
db.get_unique_meta("variable")
# Out:
# ['AR5 climate diagnostics|Temperature|Global Mean|MAGICC6|MED',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|BC',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|C2F6',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|C6F14',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|CH4',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|CO',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|CO2|AFOLU',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|CO2|Energy and Industrial Processes',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|HFC|HFC125',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|HFC|HFC134a',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|HFC|HFC143a',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|HFC|HFC227ea',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|HFC|HFC23',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|HFC|HFC245ca',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|HFC|HFC32',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|HFC|HFC43-10',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|N2O',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|NH3',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|NOx',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|OC',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|PFC',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|SF6',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|Sulfur',
#  'Diagnostics|MAGICC6|Harmonized Input|Emissions|VOC',
#  'Emissions|BC',
#  'Emissions|CH4',
#  'Emissions|CH4|AFOLU',
#  'Emissions|CH4|AFOLU|Agriculture|Livestock|Manure Management',
#  'Emissions|CH4|Energy',
#  'Emissions|CO',
#  'Emissions|CO2',
#  'Emissions|CO2|AFOLU',
#  'Emissions|CO2|Energy',
#  'Emissions|CO2|Energy and Industrial Processes',
#  'Emissions|CO2|Energy|Demand',
#  'Emissions|CO2|Energy|Demand|Industry',
#  'Emissions|CO2|Energy|Demand|Transportation',
#  'Emissions|CO2|Energy|Supply',
#  'Emissions|CO2|Energy|Supply|Electricity',
#  'Emissions|CO2|Industrial Processes',
#  'Emissions|F-Gases',
#  'Emissions|HFC|HFC125',
#  'Emissions|HFC|HFC134a',
#  'Emissions|HFC|HFC143a',
#  'Emissions|HFC|HFC227ea',
#  'Emissions|HFC|HFC23',
#  'Emissions|HFC|HFC245fa',
#  'Emissions|HFC|HFC32',
#  'Emissions|HFC|HFC43-10',
#  'Emissions|Kyoto Gases',
#  'Emissions|N2O',
#  'Emissions|N2O|AFOLU',
#  'Emissions|N2O|AFOLU|Agriculture|Livestock|Manure Management',
#  'Emissions|N2O|AFOLU|Agriculture|Managed Soils',
#  'Emissions|NH3',
#  'Emissions|NOx',
#  'Emissions|OC',
#  'Emissions|PFC',
#  'Emissions|SF6',
#  'Emissions|Sulfur',
#  'Emissions|VOC',
#  'Emissions|CH4|AFOLU|Agriculture|Livestock|Enteric Fermentation',
#  'Emissions|CH4|AFOLU|Agriculture|Rice',
#  'Emissions|CO2|Energy|Demand|Residential and Commercial',
#  'Emissions|CF4',
#  'Emissions|CH4|Industrial Processes',
#  'Emissions|HFC',
#  'Emissions|N2O|Energy',
#  'Emissions|N2O|Industrial Processes',
#  'Emissions|Upstream|CO2|Final Energy|Industry|Electricity',
#  'Emissions|Upstream|CO2|Final Energy|Industry|Heat',
#  'Emissions|Upstream|CO2|Final Energy|Residential and Commercial|Electricity',
#  'Emissions|Upstream|CO2|Final Energy|Residential and Commercial|Heat',
#  'Emissions|Upstream|CO2|Final Energy|Transportation|Electricity',
#  'Emissions|CO2|Other']

# %%
use_db_harmonised = True

if not use_db_harmonised:
    ghg_vars = [
        "Emissions|CO2|Energy and Industrial Processes",
        "Emissions|CH4",
        "Emissions|N2O",
        "Emissions|HFC|*",
    ]

else:
    ghg_vars = [
        "*Harmonized Input*Emissions|CO2|Energy and Industrial Processes",
        "*Harmonized Input*Emissions|CH4",
        "*Harmonized Input*Emissions|N2O",
        "*Harmonized Input*Emissions|HFC|*",
    ]

# %%
db["unit"] = db["unit"].apply(lambda x: x.replace("-", ""))
gwp = "AR6GWP100"

db_ghgs = (
    db.filter(variable=ghg_vars, year=range(2010, 2100 + 1)).timeseries().reset_index()
)

if use_db_harmonised:

    def fix_unit(row):
        unit = row.unit
        variable = row.variable
        if "HFC" in row.variable:
            unit = f"{unit}{row.variable.split('|')[-1]} / yr"
        else:
            unit = f"{unit} / yr"

        return unit.replace("-", "")

    db_ghgs["unit"] = db_ghgs[["variable", "unit"]].apply(fix_unit, axis=1)
    db_ghgs = scmdata.ScmRun(db_ghgs)

ghg_emms = (
    db_ghgs.resample("AS")
    .convert_unit("Gt CO2 / yr", context=gwp)
    .process_over(
        "variable",
        "sum",
        min_count=1,
        op_cols={"variable": "Emissions|GHG"},
        as_run=True,
    )
)
ghg_emms
# Out:
# <ScmRun (timeseries: 234, timepoints: 91)>
# Time:
# 	Start: 2010-01-01T00:00:00
# 	End: 2100-01-01T00:00:00
# Meta:
# 	            model                   model_scenario region            scenario         unit unit_context       variable  version
# 	0    AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1000f  World  EN_INDCi2030_1000f  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	1    AIM/CGE V2.2   AIM/CGE V2.2_EN_INDCi2030_1200  World   EN_INDCi2030_1200  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	2    AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1200f  World  EN_INDCi2030_1200f  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	3    AIM/CGE V2.2   AIM/CGE V2.2_EN_INDCi2030_1400  World   EN_INDCi2030_1400  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	4    AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1400f  World  EN_INDCi2030_1400f  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	5    AIM/CGE V2.2   AIM/CGE V2.2_EN_INDCi2030_1600  World   EN_INDCi2030_1600  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	6    AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1600f  World  EN_INDCi2030_1600f  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	7    AIM/CGE V2.2   AIM/CGE V2.2_EN_INDCi2030_1800  World   EN_INDCi2030_1800  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	8    AIM/CGE V2.2  AIM/CGE V2.2_EN_INDCi2030_1800f  World  EN_INDCi2030_1800f  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	9    AIM/CGE V2.2   AIM/CGE V2.2_EN_INDCi2030_800f  World   EN_INDCi2030_800f  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	..            ...                              ...    ...                 ...          ...          ...            ...      ...
# 	224     WITCH 5.0         WITCH 5.0_EN_NPi2020_600  World      EN_NPi2020_600  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	225     WITCH 5.0        WITCH 5.0_EN_NPi2020_600f  World     EN_NPi2020_600f  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	226     WITCH 5.0         WITCH 5.0_EN_NPi2020_700  World      EN_NPi2020_700  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	227     WITCH 5.0        WITCH 5.0_EN_NPi2020_700f  World     EN_NPi2020_700f  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	228     WITCH 5.0         WITCH 5.0_EN_NPi2020_800  World      EN_NPi2020_800  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	229     WITCH 5.0        WITCH 5.0_EN_NPi2020_800f  World     EN_NPi2020_800f  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	230     WITCH 5.0         WITCH 5.0_EN_NPi2020_900  World      EN_NPi2020_900  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	231     WITCH 5.0        WITCH 5.0_EN_NPi2020_900f  World     EN_NPi2020_900f  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	232     WITCH 5.0             WITCH 5.0_EN_NPi2100  World          EN_NPi2100  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
# 	233     WITCH 5.0            WITCH 5.0_EN_NoPolicy  World         EN_NoPolicy  Gt CO2 / yr    AR6GWP100  Emissions|GHG        2
#
# 	[234 rows x 8 columns]

# %%
ghg_emms.lineplot(style="model", legend=False)
# Out:
# <AxesSubplot:xlabel='time', ylabel='Gt CO2 / yr'>

# %%
scenario_a_2050_ghg_year = 2050
scenario_a_2050_ghg_emms = ndc_emissions.filter(
    year=scenario_a_2050_ghg_year
).values.squeeze()
scenario_a_2050_ghg_emms_unit = "GtCO2 / yr"
keep_closest_n = 25
scenario_a_2050_ghg_emms
# Out:
# array(28.6289183)

# %%
close_engage_scenarios = (
    (
        ghg_emms.filter(year=scenario_a_2050_ghg_year)
        .convert_unit(scenario_a_2050_ghg_emms_unit, context=gwp)
        .timeseries(time_axis="year")
        - scenario_a_2050_ghg_emms
    )
    .abs()
    .sort_values(by=scenario_a_2050_ghg_year, ascending=True)
    .iloc[:keep_closest_n, :]
)
close_engage_scenarios = close_engage_scenarios.index.get_level_values(
    "model_scenario"
).tolist()
close_engage_scenarios
# Out:
# ['WITCH 5.0_EN_NPi2020_1400',
#  'TIAM-ECN 1.1_EN_NPi2020_1000f',
#  'AIM/CGE V2.2_EN_INDCi2030_1200',
#  'WITCH 5.0_EN_NPi2020_1400f',
#  'POLES-JRC ENGAGE_EN_INDCi2030_1400',
#  'IMAGE 3.0_EN_INDCi2030_1400',
#  'IMAGE 3.0_EN_INDCi2030_1400f',
#  'AIM/CGE V2.2_EN_INDCi2030_1000f',
#  'WITCH 5.0_EN_INDCi2030_1400f',
#  'POLES-JRC ENGAGE_EN_INDCi2030_1400f',
#  'WITCH 5.0_EN_INDCi2030_1400',
#  'AIM/CGE V2.2_EN_NPi2020_800f',
#  'IMAGE 3.0_EN_NPi2020_1400f',
#  'COFFEE 1.1_EN_INDCi2030_700f',
#  'COFFEE 1.1_EN_NPi2020_600f',
#  'POLES-JRC ENGAGE_EN_NPi2020_1200f',
#  'AIM/CGE V2.2_EN_NPi2020_900f',
#  'TIAM-ECN 1.1_EN_INDCi2030_1000f',
#  'COFFEE 1.1_EN_NPi2020_1000',
#  'COFFEE 1.1_EN_NPi2020_700f',
#  'POLES-JRC ENGAGE_EN_NPi2020_1200',
#  'WITCH 5.0_EN_INDCi2030_1600',
#  'WITCH 5.0_EN_INDCi2030_1600f',
#  'AIM/CGE V2.2_EN_NPi2020_1000',
#  'WITCH 5.0_EN_NPi2020_1200f']

# %%
ghg_emms.filter(year=range(2040, 2060 + 1), model_scenario=close_engage_scenarios).lineplot(style="model_scenario", legend=False)
# Out:
# <AxesSubplot:xlabel='time', ylabel='Gt CO2 / yr'>

# %%
tmp = ghg_emms.filter(model_scenario=close_engage_scenarios)

ax = tmp.lineplot(hue="model_scenario", legend=False)
ndc_emissions.lineplot(ax=ax, color="black", hue=None)
ax.set_title("Emissions|Kyoto GHG excl CO2 AFOLU (AR6GWP100)")
ax.grid()
plt.show()

tmp["model"] = "model"
tmp["scenario"] = "scenario"
ax, _ = tmp.plumeplot(
    quantile_over=("model_scenario",), hue_var="variable", hue_label="Variable"
)
ndc_emissions.lineplot(ax=ax, color="black", hue=None)
ax.set_title("Emissions|Kyoto GHG excl CO2 AFOLU (AR6GWP100)")
ax.grid()
plt.show()

ax, _ = (
    tmp.filter(year=range(2015, 2101))
    .integrate()
    .convert_unit("GtCO2", context=gwp)
    .plumeplot(
        quantile_over=("model_scenario",), hue_var="variable", hue_label="Variable"
    )
)
ndc_emissions.filter(year=range(2015, 2101)).integrate().convert_unit(
    "GtCO2", context=gwp
).lineplot(ax=ax, color="black", hue=None)
ax.set_title("Cumulative Emissions|Kyoto GHG excl CO2 AFOLU (AR6GWP100)")
ax.grid()
plt.show()

# %%
tmp = db.filter(
    model_scenario=close_engage_scenarios,
    variable="AR5 climate diagnostics|Temperature|Global Mean|MAGICC6|MED",
)

ax = tmp.lineplot(hue="model_scenario", legend=False)
ndc_temperatures.lineplot(ax=ax, color="black", hue=None)
ax.grid()
plt.show()

tmp["model"] = "model"
tmp["scenario"] = "scenario"
ax, _ = tmp.plumeplot(
    quantile_over=("model_scenario",), hue_var="variable", hue_label="Variable"
)
ndc_temperatures.lineplot(ax=ax, color="black", hue=None)
ax.grid()
plt.show()
